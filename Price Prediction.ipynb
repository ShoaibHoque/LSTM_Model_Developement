# %%
# importing necessary libraries
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go

# %%
data_5 = pd.read_csv('data_5.csv')
data_15 = pd.read_csv('data_15.csv')
data_30 = pd.read_csv('data_30.csv')

# %%
data_5
# Out:
#                      time      open      high       low     close  \
# 0     2024-05-21 05:10:00  70904.68  71007.76  70876.06  70918.41
# 1     2024-05-21 05:15:00  70918.41  71029.72  70916.02  70944.39
# 2     2024-05-21 05:20:00  70944.39  70975.49  70877.16  70918.09
# 3     2024-05-21 05:25:00  70918.09  71014.92  70902.19  70955.74
# 4     2024-05-21 05:30:00  70955.74  71158.57  70951.72  71141.43
# ...                   ...       ...       ...       ...       ...
# 9995  2024-06-25 08:30:00  61245.30  61279.20  61220.16  61224.03
# 9996  2024-06-25 08:35:00  61226.31  61239.93  61049.88  61065.57
# 9997  2024-06-25 08:40:00  61065.98  61122.70  60943.66  60969.89
# 9998  2024-06-25 08:45:00  60964.38  61023.73  60930.79  60938.62
# 9999  2024-06-25 08:50:00  60938.62  60981.38  60901.27  60977.43
#
#       tick_volume  spread  real_volume
# 0             708    1638            0
# 1             605    1624            0
# 2             640    1708            0
# 3             619    1952            0
# 4             651    1500            0
# ...           ...     ...          ...
# 9995          711    1296            0
# 9996          938     835            0
# 9997          780    1500            0
# 9998          822    1428            0
# 9999          516    1327            0
#
# [10000 rows x 8 columns]

# %% [markdown]
# ### EDA

# %%
from autoviz.AutoViz_Class import AutoViz_Class

AV = AutoViz_Class()

dft = AV.AutoViz(
    'data_5.csv',
    sep=",",
    depVar="close",
    dfte=None,
    header=0,
    verbose=1,
    lowess=False,
    chart_format="jpg",
    save_plot_dir=None
)
# Out:
# Shape of your Data Set loaded: (10000, 8)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     Number of Numeric Columns =  3
#     Number of Integer-Categorical Columns =  2
#     Number of String-Categorical Columns =  0
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  0
#     Number of Numeric-Boolean Columns =  0
#     Number of Discrete String Columns =  0
#     Number of NLP String Columns =  0
#     Number of Date Time Columns =  0
#     Number of ID Columns =  1
#     Number of Columns to Delete =  1
#     7 Predictors classified...
#         2 variable(s) removed since they were ID or low-information variables
#         List of variables removed: ['time', 'real_volume']
#
# ################ Regression problem #####################
# To fix these data quality issues in the dataset, import FixDQ from autoviz...
#     All variables classified into correct types.
# <style type="text/css">
# #T_37e93_row0_col0, #T_37e93_row0_col2, #T_37e93_row0_col5, #T_37e93_row1_col0, #T_37e93_row1_col2, #T_37e93_row1_col5, #T_37e93_row2_col0, #T_37e93_row2_col2, #T_37e93_row2_col5, #T_37e93_row3_col0, #T_37e93_row3_col2, #T_37e93_row3_col5, #T_37e93_row4_col0, #T_37e93_row4_col2, #T_37e93_row4_col5, #T_37e93_row5_col0, #T_37e93_row5_col2, #T_37e93_row5_col5 {
#   font-family: Segoe UI;
# }
# #T_37e93_row0_col1, #T_37e93_row1_col1, #T_37e93_row2_col1, #T_37e93_row3_col1, #T_37e93_row3_col3, #T_37e93_row3_col4, #T_37e93_row4_col1, #T_37e93_row4_col3, #T_37e93_row5_col1 {
#   background-color: #fff5f0;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_37e93_row0_col3, #T_37e93_row5_col3 {
#   background-color: #69000d;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_37e93_row0_col4, #T_37e93_row1_col3, #T_37e93_row1_col4, #T_37e93_row2_col4, #T_37e93_row5_col4 {
#   background-color: #67000d;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_37e93_row2_col3 {
#   background-color: #6d010e;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_37e93_row4_col4 {
#   background-color: #ffede5;
#   color: #000000;
#   font-family: Segoe UI;
# }
# </style>
# <table id="T_37e93">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_37e93_level0_col0" class="col_heading level0 col0" >Data Type</th>
#       <th id="T_37e93_level0_col1" class="col_heading level0 col1" >Missing Values%</th>
#       <th id="T_37e93_level0_col2" class="col_heading level0 col2" >Unique Values%</th>
#       <th id="T_37e93_level0_col3" class="col_heading level0 col3" >Minimum Value</th>
#       <th id="T_37e93_level0_col4" class="col_heading level0 col4" >Maximum Value</th>
#       <th id="T_37e93_level0_col5" class="col_heading level0 col5" >DQ Issue</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_37e93_level0_row0" class="row_heading level0 row0" >open</th>
#       <td id="T_37e93_row0_col0" class="data row0 col0" >float64</td>
#       <td id="T_37e93_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_37e93_row0_col2" class="data row0 col2" >NA</td>
#       <td id="T_37e93_row0_col3" class="data row0 col3" >58854.320000</td>
#       <td id="T_37e93_row0_col4" class="data row0 col4" >71905.550000</td>
#       <td id="T_37e93_row0_col5" class="data row0 col5" >Column has 237 outliers greater than upper bound (74039.12) or lower than lower bound(61485.03). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_37e93_level0_row1" class="row_heading level0 row1" >high</th>
#       <td id="T_37e93_row1_col0" class="data row1 col0" >float64</td>
#       <td id="T_37e93_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_37e93_row1_col2" class="data row1 col2" >NA</td>
#       <td id="T_37e93_row1_col3" class="data row1 col3" >59145.470000</td>
#       <td id="T_37e93_row1_col4" class="data row1 col4" >71933.660000</td>
#       <td id="T_37e93_row1_col5" class="data row1 col5" >Column has 232 outliers greater than upper bound (74089.25) or lower than lower bound(61504.51). Cap them or remove them., Column has a high correlation with ['open']. Consider dropping one of them.</td>
#     </tr>
#     <tr>
#       <th id="T_37e93_level0_row2" class="row_heading level0 row2" >low</th>
#       <td id="T_37e93_row2_col0" class="data row2 col0" >float64</td>
#       <td id="T_37e93_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_37e93_row2_col2" class="data row2 col2" >NA</td>
#       <td id="T_37e93_row2_col3" class="data row2 col3" >58384.530000</td>
#       <td id="T_37e93_row2_col4" class="data row2 col4" >71833.510000</td>
#       <td id="T_37e93_row2_col5" class="data row2 col5" >Column has 242 outliers greater than upper bound (73980.33) or lower than lower bound(61477.78). Cap them or remove them., Column has a high correlation with ['open', 'high']. Consider dropping one of them.</td>
#     </tr>
#     <tr>
#       <th id="T_37e93_level0_row3" class="row_heading level0 row3" >tick_volume</th>
#       <td id="T_37e93_row3_col0" class="data row3 col0" >int64</td>
#       <td id="T_37e93_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_37e93_row3_col2" class="data row3 col2" >16</td>
#       <td id="T_37e93_row3_col3" class="data row3 col3" >3.000000</td>
#       <td id="T_37e93_row3_col4" class="data row3 col4" >1962.000000</td>
#       <td id="T_37e93_row3_col5" class="data row3 col5" >Column has 13 outliers greater than upper bound (1867.00) or lower than lower bound(-333.00). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_37e93_level0_row4" class="row_heading level0 row4" >spread</th>
#       <td id="T_37e93_row4_col0" class="data row4 col0" >int64</td>
#       <td id="T_37e93_row4_col1" class="data row4 col1" >0.000000</td>
#       <td id="T_37e93_row4_col2" class="data row4 col2" >19</td>
#       <td id="T_37e93_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_37e93_row4_col4" class="data row4 col4" >5373.000000</td>
#       <td id="T_37e93_row4_col5" class="data row4 col5" >Column has 318 outliers greater than upper bound (2327.62) or lower than lower bound(-105.38). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_37e93_level0_row5" class="row_heading level0 row5" >close</th>
#       <td id="T_37e93_row5_col0" class="data row5 col0" >float64</td>
#       <td id="T_37e93_row5_col1" class="data row5 col1" >0.000000</td>
#       <td id="T_37e93_row5_col2" class="data row5 col2" >98</td>
#       <td id="T_37e93_row5_col3" class="data row5 col3" >58849.240000</td>
#       <td id="T_37e93_row5_col4" class="data row5 col4" >71905.200000</td>
#       <td id="T_37e93_row5_col5" class="data row5 col5" >Target column</td>
#     </tr>
#   </tbody>
# </table>
# Number of All Scatter Plots = 6
# All Plots done
# Time to run AutoViz = 9 seconds
#
#  ###################### AUTO VISUALIZATION Completed ########################

# %%
dft = AV.AutoViz(
    'data_15.csv',
    sep=",",
    depVar="close",
    dfte=None,
    header=0,
    verbose=1,
    lowess=False,
    chart_format="jpg",
    save_plot_dir=None
)
# Out:
# Shape of your Data Set loaded: (10000, 8)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     Number of Numeric Columns =  3
#     Number of Integer-Categorical Columns =  2
#     Number of String-Categorical Columns =  0
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  0
#     Number of Numeric-Boolean Columns =  0
#     Number of Discrete String Columns =  0
#     Number of NLP String Columns =  0
#     Number of Date Time Columns =  0
#     Number of ID Columns =  1
#     Number of Columns to Delete =  1
#     7 Predictors classified...
#         2 variable(s) removed since they were ID or low-information variables
#         List of variables removed: ['time', 'real_volume']
#
# ################ Regression problem #####################
# To fix these data quality issues in the dataset, import FixDQ from autoviz...
#     All variables classified into correct types.
# <style type="text/css">
# #T_45711_row0_col0, #T_45711_row0_col2, #T_45711_row0_col5, #T_45711_row1_col0, #T_45711_row1_col2, #T_45711_row1_col5, #T_45711_row2_col0, #T_45711_row2_col2, #T_45711_row2_col5, #T_45711_row3_col0, #T_45711_row3_col2, #T_45711_row3_col5, #T_45711_row4_col0, #T_45711_row4_col2, #T_45711_row4_col5, #T_45711_row5_col0, #T_45711_row5_col2, #T_45711_row5_col5 {
#   font-family: Segoe UI;
# }
# #T_45711_row0_col1, #T_45711_row1_col1, #T_45711_row2_col1, #T_45711_row3_col1, #T_45711_row3_col3, #T_45711_row3_col4, #T_45711_row4_col1, #T_45711_row4_col3, #T_45711_row5_col1 {
#   background-color: #fff5f0;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_45711_row0_col3, #T_45711_row2_col4, #T_45711_row5_col3 {
#   background-color: #69000d;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_45711_row0_col4, #T_45711_row1_col3, #T_45711_row1_col4, #T_45711_row5_col4 {
#   background-color: #67000d;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_45711_row2_col3 {
#   background-color: #6b010e;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_45711_row4_col4 {
#   background-color: #fcb499;
#   color: #000000;
#   font-family: Segoe UI;
# }
# </style>
# <table id="T_45711">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_45711_level0_col0" class="col_heading level0 col0" >Data Type</th>
#       <th id="T_45711_level0_col1" class="col_heading level0 col1" >Missing Values%</th>
#       <th id="T_45711_level0_col2" class="col_heading level0 col2" >Unique Values%</th>
#       <th id="T_45711_level0_col3" class="col_heading level0 col3" >Minimum Value</th>
#       <th id="T_45711_level0_col4" class="col_heading level0 col4" >Maximum Value</th>
#       <th id="T_45711_level0_col5" class="col_heading level0 col5" >DQ Issue</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_45711_level0_row0" class="row_heading level0 row0" >open</th>
#       <td id="T_45711_row0_col0" class="data row0 col0" >float64</td>
#       <td id="T_45711_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_45711_row0_col2" class="data row0 col2" >NA</td>
#       <td id="T_45711_row0_col3" class="data row0 col3" >56687.160000</td>
#       <td id="T_45711_row0_col4" class="data row0 col4" >73646.490000</td>
#       <td id="T_45711_row0_col5" class="data row0 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_45711_level0_row1" class="row_heading level0 row1" >high</th>
#       <td id="T_45711_row1_col0" class="data row1 col0" >float64</td>
#       <td id="T_45711_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_45711_row1_col2" class="data row1 col2" >NA</td>
#       <td id="T_45711_row1_col3" class="data row1 col3" >56918.000000</td>
#       <td id="T_45711_row1_col4" class="data row1 col4" >73843.750000</td>
#       <td id="T_45711_row1_col5" class="data row1 col5" >Column has a high correlation with ['open']. Consider dropping one of them.</td>
#     </tr>
#     <tr>
#       <th id="T_45711_level0_row2" class="row_heading level0 row2" >low</th>
#       <td id="T_45711_row2_col0" class="data row2 col0" >float64</td>
#       <td id="T_45711_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_45711_row2_col2" class="data row2 col2" >NA</td>
#       <td id="T_45711_row2_col3" class="data row2 col3" >56448.280000</td>
#       <td id="T_45711_row2_col4" class="data row2 col4" >73439.480000</td>
#       <td id="T_45711_row2_col5" class="data row2 col5" >Column has a high correlation with ['open', 'high']. Consider dropping one of them.</td>
#     </tr>
#     <tr>
#       <th id="T_45711_level0_row3" class="row_heading level0 row3" >tick_volume</th>
#       <td id="T_45711_row3_col0" class="data row3 col0" >int64</td>
#       <td id="T_45711_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_45711_row3_col2" class="data row3 col2" >43</td>
#       <td id="T_45711_row3_col3" class="data row3 col3" >3.000000</td>
#       <td id="T_45711_row3_col4" class="data row3 col4" >6576.000000</td>
#       <td id="T_45711_row3_col5" class="data row3 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_45711_level0_row4" class="row_heading level0 row4" >spread</th>
#       <td id="T_45711_row4_col0" class="data row4 col0" >int64</td>
#       <td id="T_45711_row4_col1" class="data row4 col1" >0.000000</td>
#       <td id="T_45711_row4_col2" class="data row4 col2" >18</td>
#       <td id="T_45711_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_45711_row4_col4" class="data row4 col4" >24750.000000</td>
#       <td id="T_45711_row4_col5" class="data row4 col5" >Column has 140 outliers greater than upper bound (2489.50) or lower than lower bound(-522.50). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_45711_level0_row5" class="row_heading level0 row5" >close</th>
#       <td id="T_45711_row5_col0" class="data row5 col0" >float64</td>
#       <td id="T_45711_row5_col1" class="data row5 col1" >0.000000</td>
#       <td id="T_45711_row5_col2" class="data row5 col2" >99</td>
#       <td id="T_45711_row5_col3" class="data row5 col3" >56689.660000</td>
#       <td id="T_45711_row5_col4" class="data row5 col4" >73646.400000</td>
#       <td id="T_45711_row5_col5" class="data row5 col5" >Target column</td>
#     </tr>
#   </tbody>
# </table>
# Number of All Scatter Plots = 6
# All Plots done
# Time to run AutoViz = 8 seconds
#
#  ###################### AUTO VISUALIZATION Completed ########################

# %%
dft = AV.AutoViz(
    'data_30.csv',
    sep=",",
    depVar="close",
    dfte=None,
    header=0,
    verbose=1,
    lowess=False,
    chart_format="jpg",
    save_plot_dir=None
)
# Out:
# Shape of your Data Set loaded: (10000, 8)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     Number of Numeric Columns =  3
#     Number of Integer-Categorical Columns =  2
#     Number of String-Categorical Columns =  0
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  0
#     Number of Numeric-Boolean Columns =  0
#     Number of Discrete String Columns =  0
#     Number of NLP String Columns =  0
#     Number of Date Time Columns =  0
#     Number of ID Columns =  1
#     Number of Columns to Delete =  1
#     7 Predictors classified...
#         2 variable(s) removed since they were ID or low-information variables
#         List of variables removed: ['time', 'real_volume']
#
# ################ Regression problem #####################
# To fix these data quality issues in the dataset, import FixDQ from autoviz...
#     All variables classified into correct types.
# <style type="text/css">
# #T_be3ce_row0_col0, #T_be3ce_row0_col2, #T_be3ce_row0_col5, #T_be3ce_row1_col0, #T_be3ce_row1_col2, #T_be3ce_row1_col5, #T_be3ce_row2_col0, #T_be3ce_row2_col2, #T_be3ce_row2_col5, #T_be3ce_row3_col0, #T_be3ce_row3_col2, #T_be3ce_row3_col5, #T_be3ce_row4_col0, #T_be3ce_row4_col2, #T_be3ce_row4_col5, #T_be3ce_row5_col0, #T_be3ce_row5_col2, #T_be3ce_row5_col5 {
#   font-family: Segoe UI;
# }
# #T_be3ce_row0_col1, #T_be3ce_row1_col1, #T_be3ce_row2_col1, #T_be3ce_row3_col1, #T_be3ce_row3_col3, #T_be3ce_row4_col1, #T_be3ce_row4_col3, #T_be3ce_row4_col4, #T_be3ce_row5_col1 {
#   background-color: #fff5f0;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_be3ce_row0_col3, #T_be3ce_row0_col4, #T_be3ce_row1_col3, #T_be3ce_row1_col4, #T_be3ce_row2_col3, #T_be3ce_row5_col3, #T_be3ce_row5_col4 {
#   background-color: #67000d;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_be3ce_row2_col4 {
#   background-color: #69000d;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_be3ce_row3_col4 {
#   background-color: #fff0e8;
#   color: #000000;
#   font-family: Segoe UI;
# }
# </style>
# <table id="T_be3ce">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_be3ce_level0_col0" class="col_heading level0 col0" >Data Type</th>
#       <th id="T_be3ce_level0_col1" class="col_heading level0 col1" >Missing Values%</th>
#       <th id="T_be3ce_level0_col2" class="col_heading level0 col2" >Unique Values%</th>
#       <th id="T_be3ce_level0_col3" class="col_heading level0 col3" >Minimum Value</th>
#       <th id="T_be3ce_level0_col4" class="col_heading level0 col4" >Maximum Value</th>
#       <th id="T_be3ce_level0_col5" class="col_heading level0 col5" >DQ Issue</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_be3ce_level0_row0" class="row_heading level0 row0" >open</th>
#       <td id="T_be3ce_row0_col0" class="data row0 col0" >float64</td>
#       <td id="T_be3ce_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_be3ce_row0_col2" class="data row0 col2" >NA</td>
#       <td id="T_be3ce_row0_col3" class="data row0 col3" >37183.620000</td>
#       <td id="T_be3ce_row0_col4" class="data row0 col4" >73636.900000</td>
#       <td id="T_be3ce_row0_col5" class="data row0 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_be3ce_level0_row1" class="row_heading level0 row1" >high</th>
#       <td id="T_be3ce_row1_col0" class="data row1 col0" >float64</td>
#       <td id="T_be3ce_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_be3ce_row1_col2" class="data row1 col2" >NA</td>
#       <td id="T_be3ce_row1_col3" class="data row1 col3" >37262.040000</td>
#       <td id="T_be3ce_row1_col4" class="data row1 col4" >73843.750000</td>
#       <td id="T_be3ce_row1_col5" class="data row1 col5" >Column has a high correlation with ['open']. Consider dropping one of them.</td>
#     </tr>
#     <tr>
#       <th id="T_be3ce_level0_row2" class="row_heading level0 row2" >low</th>
#       <td id="T_be3ce_row2_col0" class="data row2 col0" >float64</td>
#       <td id="T_be3ce_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_be3ce_row2_col2" class="data row2 col2" >NA</td>
#       <td id="T_be3ce_row2_col3" class="data row2 col3" >37139.090000</td>
#       <td id="T_be3ce_row2_col4" class="data row2 col4" >73406.670000</td>
#       <td id="T_be3ce_row2_col5" class="data row2 col5" >Column has a high correlation with ['open', 'high']. Consider dropping one of them.</td>
#     </tr>
#     <tr>
#       <th id="T_be3ce_level0_row3" class="row_heading level0 row3" >tick_volume</th>
#       <td id="T_be3ce_row3_col0" class="data row3 col0" >int64</td>
#       <td id="T_be3ce_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_be3ce_row3_col2" class="data row3 col2" >57</td>
#       <td id="T_be3ce_row3_col3" class="data row3 col3" >12.000000</td>
#       <td id="T_be3ce_row3_col4" class="data row3 col4" >13149.000000</td>
#       <td id="T_be3ce_row3_col5" class="data row3 col5" >Column has 35 outliers greater than upper bound (10648.12) or lower than lower bound(-2164.88). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_be3ce_level0_row4" class="row_heading level0 row4" >spread</th>
#       <td id="T_be3ce_row4_col0" class="data row4 col0" >int64</td>
#       <td id="T_be3ce_row4_col1" class="data row4 col1" >0.000000</td>
#       <td id="T_be3ce_row4_col2" class="data row4 col2" >16</td>
#       <td id="T_be3ce_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_be3ce_row4_col4" class="data row4 col4" >11049.000000</td>
#       <td id="T_be3ce_row4_col5" class="data row4 col5" >Column has 135 outliers greater than upper bound (1784.38) or lower than lower bound(-176.62). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_be3ce_level0_row5" class="row_heading level0 row5" >close</th>
#       <td id="T_be3ce_row5_col0" class="data row5 col0" >float64</td>
#       <td id="T_be3ce_row5_col1" class="data row5 col1" >0.000000</td>
#       <td id="T_be3ce_row5_col2" class="data row5 col2" >99</td>
#       <td id="T_be3ce_row5_col3" class="data row5 col3" >37211.620000</td>
#       <td id="T_be3ce_row5_col4" class="data row5 col4" >73639.900000</td>
#       <td id="T_be3ce_row5_col5" class="data row5 col5" >Target column</td>
#     </tr>
#   </tbody>
# </table>
# Number of All Scatter Plots = 6
# All Plots done
# Time to run AutoViz = 8 seconds
#
#  ###################### AUTO VISUALIZATION Completed ########################
